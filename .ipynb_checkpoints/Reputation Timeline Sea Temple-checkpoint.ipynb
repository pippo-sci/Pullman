# %% [markdown]
# # Customer review timeline (of Sea Temple Port Douglas)

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib as plt
plt.rcParams["figure.figsize"] = [12, 9]
import scipy.stats as stats
from __future__ import unicode_literals

# %%
data = pd.read_csv('C:/Users/Cami/Google Drive/Python/Pullman/tripullman/test.csv', encoding= "utf-8")
#C:\Users\Cami\Google Drive\Python\Pullman\tripullman

# %%
data.shape
# Out:
# (1880, 16)

# %%
data.head(2)
# Out:
#        N_opinion  Nivel                                      Op_sobre  \
# 0  1,915 reviews  6      Pullman Port Douglas Sea Temple Resort & Spa
# 1  1,915 reviews  7      Pullman Port Douglas Sea Temple Resort & Spa
#
#       autor  califica  calificacion  \
# 0  Neil O    30        4.5
# 1  Daniel L  50        4.5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                   comentario  \
# 0  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
# 1  We have stayed now 2 times. The staff have always been fantastic and the service amazing. The pool is the show piece of the hotel and we basically lived there every day.
#
#                                             direccion              fecha  \
# 0  Mitre St,Port Douglas, Queensland 4877, ,Australia  14 September 2018
# 1  Mitre St,Port Douglas, Queensland 4877, ,Australia  2 September 2018
#
#    lugar                                        nombre      region   tipo  \
# 0 NaN     Pullman Port Douglas Sea Temple Resort & Spa  Queensland  Hotel
# 1 NaN     Pullman Port Douglas Sea Temple Resort & Spa  Queensland  Hotel
#
#              tipo1                           titulo  \
# 0   of 42 , of 42   First family holiday
# 1   of 42 , of 42   The best hotel in port Douglas
#
#                                                                                                                                            web
# 0  https://www.tripadvisor.com.au/Hotel_Review-g255070-d619468-Reviews-Pullman_Port_Douglas_Sea_Temple_Resort_Spa-Port_Douglas_Queensland.html
# 1  https://www.tripadvisor.com.au/Hotel_Review-g255070-d619468-Reviews-Pullman_Port_Douglas_Sea_Temple_Resort_Spa-Port_Douglas_Queensland.html

# %% [markdown]
# ## Lets see how califications

# %%
data.califica.describe()
# Out:
# count    1880.000000
# mean     42.611702
# std      9.860025
# min      10.000000
# 25%      40.000000
# 50%      50.000000
# 75%      50.000000
# max      50.000000
# Name: califica, dtype: float64

# %%
data.califica.value_counts().plot(kind='bar')

# %% [markdown]
# ## Timeseries
#
# First I should see how many commentaries the resort has monthly.

# %%
data['fecha2'] = pd.to_datetime(data.fecha,format='%d %B %Y')

# %%
dfd = data.copy()
dfd.index = dfd['fecha2']
dfd.index = pd.to_datetime(dfd.index)
dfd = dfd.sort_values('fecha2')

# %%
barra=dfd.califica.copy()
barra=barra.resample(rule='M').count()
barra.plot(kind='bar')

# %% [markdown]
# OK. So since 2012 comments are 20 each month. reaching a pick in 2017 of up to 40 comments in a single month.
#
# ### Calification through time
#
# Let's calculate the mean of calification of every month.

# %%
linea=dfd.califica.copy()
linea=linea.resample(rule='M').mean()
linea.plot(kind='line')

# %% [markdown]
# It seems that before 2012 -when there is few comments- the mean looks volatile, but then moves aroud 4.5 and its been slighly decreasing. More stable version could be the accumulate version.

# %%
lineaAccum=dfd.califica.copy()
lineaAccum=lineaAccum.expanding().mean()
lineaAccum.plot(kind='line')

# %%
#1880
#lineaAccum[100:] #.resample(rule='M').mean()

# %% [markdown]
# ## Look for meaning (most significative bi-grams)

# %% [markdown]
# #### Extract most common bi-grams

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer

stp = nltk.corpus.stopwords.words('English') 
data.comentario.dropna(inplace=True)

vectorizer = TfidfVectorizer(lowercase=True, stop_words=stp[:130] ,ngram_range = (2,3), min_df=5).fit(data.comentario)
full_matrix = vectorizer.transform(data.comentario)
# Out:
# C:\Users\Cami\Anaconda2\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
def display_scores(vectorizer, tfidf_result,n=50):
    # http://stackoverflow.com/questions/16078015/
    scores = zip(vectorizer.get_feature_names(),
                 np.asarray(tfidf_result.sum(axis=0)).ravel())
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
    for item in sorted_scores[:n]:
        print "{0:50} Score: {1}".format(item[0], item[1])
        
display_scores(vectorizer,full_matrix,25)
# Out:
# sea temple                                         Score: 77.8930934506
# port douglas                                       Score: 66.4978893323
# pool bar                                           Score: 23.1369538374
# stayed nights                                      Score: 21.9780355252
# staff friendly                                     Score: 20.0093699009
# plunge pool                                        Score: 18.0582930426
# front desk                                         Score: 17.9208931917
# pool area                                          Score: 17.6966140757
# stayed sea                                         Score: 17.61787571
# stayed sea temple                                  Score: 17.61787571
# bedroom apartment                                  Score: 17.602594302
# two bedroom                                        Score: 17.5238704256
# temple port                                        Score: 17.492274635
# temple port douglas                                Score: 17.492274635
# sea temple port                                    Score: 17.3356821352
# lagoon pool                                        Score: 16.9723788131
# room service                                       Score: 16.8514719542
# pullman sea                                        Score: 15.4398702934
# pullman sea temple                                 Score: 15.4398702934
# swimming pool                                      Score: 14.9796306981
# golf course                                        Score: 14.4070325351
# friendly helpful                                   Score: 13.9548310356
# spa room                                           Score: 13.9025908066
# bedroom penthouse                                  Score: 13.7908448413
# one best                                           Score: 13.5255258787

# %% [markdown]
# This is the most frequent combinations of words in the reviews. It doesn't seem to be meanful. Let's try another techniques.

# %% [markdown]
# ### Prepare Data to split reviews into sentences

# %% [markdown]
# Many reviews are generally positive, but they refer to different things. To make things clearer let's split the reviews into sentences. That way we could note the diference if a comment is about more than one subject.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
dm = data[['titulo','califica','comentario','fecha']].copy()
dm.dropna(inplace=True)
dm['sent']=dm.comentario.apply(sent_tokenize)
dm2= (dm['sent'].apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True).to_frame('sent').join(dm[['titulo','califica','comentario','fecha']], how='left'))

# %% [markdown]
# Check the new data set with a sentence by row

# %%
dm3=dm2.reset_index().copy()
dm3.head()
# Out:
#    index  \
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0
#
#                                                                                                                       sent  \
# 0  5 star prices and 3 star service.
# 1  We stayed in a villa with a private pool which was ok but needs updating and looks tired.
# 2  The maintenance man even said it’s so hard to keep up with all the hotels issues.
# 3  The food is bang average not just at the hotel but all round port Douglas.
# 4  The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run.
#
#                  titulo  califica  \
# 0  First family holiday  30
# 1  First family holiday  30
# 2  First family holiday  30
# 3  First family holiday  30
# 4  First family holiday  30
#
#                                                                                                                                                                                                                                                                                                                                                                                                                   comentario  \
# 0  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
# 1  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
# 2  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
# 3  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
# 4  5 star prices and 3 star service. We stayed in a villa with a private pool which was ok but needs updating and looks tired. The maintenance man even said it’s so hard to keep up with all the hotels issues. The food is bang average not just at the hotel but all round port Douglas. The staff are all great and try and make your stay nice it’s not their fault I just think this is how the hotel is run. 3 stars
#
#                fecha
# 0  14 September 2018
# 1  14 September 2018
# 2  14 September 2018
# 3  14 September 2018
# 4  14 September 2018

# %% [markdown]
# ### Detect keyphases

# %% [markdown]
# Now that the data is in order, let's try to create bigrams that represent its content. For this I am gooing to use Word2vec representación of the text.

# %% [markdown]
# ##### Keyphrases with bigrams and w2vec

# %%
"""
import nltk
from gensim.models import Phrases
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from collections import Counter

sentences = dm3.sent
bigram = Phrases()

bigram.add_vocab([sentences])

bigram_model = Word2Vec(bigram[sentences], size=100)
bigram_model_counter = Counter()
for key in bigram_model.wv.vocab.keys():
    if key not in stopwords.words("english"):
        if len(key.split("_")) > 1:
            bigram_model_counter[key] += bigram_model.wv.vocab[key].count

for key, counts in bigram_model_counter.most_common(50):
    print '{0: <20} {1}'.format(key.encode("utf-8"), counts)
"""
# Out:
# '\nimport nltk\nfrom gensim.models import Phrases\nfrom gensim.models import Word2Vec\nfrom nltk.corpus import stopwords\nfrom collections import Counter\n\nsentences = dm3.sent\nbigram = Phrases()\n\nbigram.add_vocab([sentences])\n\nbigram_model = Word2Vec(bigram[sentences], size=100)\nbigram_model_counter = Counter()\nfor key in bigram_model.wv.vocab.keys():\n    if key not in stopwords.words("english"):\n        if len(key.split("_")) > 1:\n            bigram_model_counter[key] += bigram_model.wv.vocab[key].count\n\nfor key, counts in bigram_model_counter.most_common(50):\n    print \'{0: <20} {1}\'.format(key.encode("utf-8"), counts)\n'

# %% [markdown]
# ##### Keyphrases with postagging selection

# %% [markdown]
# Another way to do it is to try to get subject and adjetives of each sentences.

# %%
import spacy
nlp = spacy.load('en_core_web_md')

dm3['new_col'] = dm3['sent'].apply(lambda x: nlp(x))

# %%
#Function to extract relevant chunks
def get_chunk(sent, chunk="NOUN"):
    chunks=[]
    dep =[]
    tt = []
    for w in sent:
        if w.pos_ == chunk:
            chunks.append(w.text)
        if w.tag_ == "JJ":
            dep.append(w.text)
        if w.dep_ == "neg":
            tt.append(w.text)       
    return chunks + tt + dep
     
dm3['keywords'] = dm3.new_col.apply(get_chunk)
keywords = dm3.keywords.apply(' '.join)

#print dm3.new_col.apply(lambda x: [(i.tag_,i.text) for i in x])

# %% [markdown]
# If we collect the most common words we could use them to classify comments later.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
commonWords = cv.fit(keywords)
kw = commonWords.transform(keywords)
display_scores(commonWords,kw,25)
# Out:
# pool                                               Score: 1556
# room                                               Score: 1101
# resort                                             Score: 970
# not                                                Score: 897
# great                                              Score: 723
# staff                                              Score: 701
# hotel                                              Score: 576
# apartment                                          Score: 531
# spa                                                Score: 487
# service                                            Score: 472
# rooms                                              Score: 437
# good                                               Score: 431
# restaurant                                         Score: 409
# area                                               Score: 403
# time                                               Score: 400
# bedroom                                            Score: 387
# nice                                               Score: 337
# beautiful                                          Score: 332
# nights                                             Score: 321
# place                                              Score: 316
# stay                                               Score: 316
# town                                               Score: 316
# food                                               Score: 315
# friendly                                           Score: 306
# beach                                              Score: 304

# %%
# Let's see if we could get something of context for each word
dm3.sent[dm3.sent.str.contains('area')].sample(20)
# Out:
# 7860    The condo was spacious with a nice kitchen, large living areas, large master bedroom/bathroom and washer/dryer in the kitchen area.
# 1651    Room appeared clean but was not, bathroom dirty kitchen didn't have enough plates,  out door couch and BBQ area was dirty and with Cobb webs.
# 6630    Pool area very kid friendly staff very friendly and helpful.
# 2421    The pool area is absolutely stunning and at night it is lit up with beautiful lanterns/flames.
# 2498    I have to say the staff everywhere, including the cleaning staff, those in the reception area and restaurant were amazingly helpful and friendly.
# 230     The dining area allows for seating under cover or pool-side.
# 911     Would have liked a play area for the kids, but they didn't have any problems coming up with their own games.
# 7462    We had a private plunge pool a BBQ area, two private car parks.
# 9381    The ambience in the bar area was spoiled, there were always hundreds of people milling around the reception area etc.
# 7155    The upstairs rooftop bbq area with spa was great too.
# 1299    The apartment was spotlessly clean including the spa on the rooftop area.
# 6734    Each villa has its own private pool and outdoor entertaining area with BBQ and beach access through a pathway close by.
# 4304    We had a balcony with a view of the pool that features a spiral staircase leading to a private rooftop spa and bar-b-q area.
# 2732    Fabulous swimming area.
# 3119    We had our own rooftop spa and bbq area that would easily fit 70 people if you wanted to host a cocktail party.
# 9110    It is located in a quiet area, is very near the beach (out the gate, down the little path and voila!)
# 3441    Downstairs had a generous sized kitchen (even had a Nespresso coffee machine), separate dining and sunken lounge areas, a downstairs toilet and laundry with washer and dryer.
# 2304    Balcony with full seating area is very pleasant on nice days.
# 4052    Breakfast was good as was location of the dining area and the guy on the bar there in the evenings, whose name escapes me is a real asset to the place.
# 8822    The penthouse has a roof top spa tub, BBQ and chill out area.
# Name: sent, dtype: object

# %% [markdown]
# ## Semi-Unsupervised Classification of text

# %% [markdown]
# Sometimes is hard try to evaluate comments through time. There is a bias toward the last comment we read and we tend to forget the first ones.
# So, for a more systematical analysis let's organize the comments to get better understanding of what they said.
#
# For this I could use representations of the text. I could try to get some descriptors as markers and show how they distribute through the time. This will allow me to make visualizations of key concepts in the text.
#
# As there is different areas within a hotel is value to identify marker refered to the work of reception, housekeeping and maintance or food and beverage departments. I found also interesting add another marker for infraestructure and environment.
#
# I cannot read every comment, so I will give a list of words that could be in for each marker. If the algorithm found similarity between que list of words and a sentence it will classify the sentence as is has the most like marker.
# As the sentences and the words on them are build as vectors (know as Word embeddings or word2vec) I assuming it will easly found "synonymous".

# %%
# We’ll use SpaCy which includes pre-trained vectors for the most common words using the GloVe Common Crawl

import spacy
from __future__ import unicode_literals
nlp2 = spacy.load('en_core_web_md')
doc = dm3['sent'].apply(lambda x: nlp2(x))

# %%
topic_labels = [
'Food & Beverage',
  'Housekeeping',
  'Front desk',
    'Environment'
]
# I give a list of words for every topic based on the most common topics
topic_keywords = [
    'food drink burger waiter chef soda wine delicious taste chips beer restaurant',
  'clean room floor sheets toilet bathroom bed spa housekeeper furniture blanket dirt',
    'desk reception luggage call welcome',
  'location atmosphere pool terrace parking beach town lobby hall'    
]

# %%
import itertools
import numpy as np

topic_keywords = [i.decode('utf-8') for i in topic_keywords]
# Use pipe to run this in parallel
topic_docs = list(nlp2.pipe(topic_keywords,
  batch_size=10000,
  n_threads=3))
topic_vectors = np.array([doc.vector 
  if doc.has_vector else doc.vocab[0].vector
  for doc in topic_docs])

# %%
keywords[:3]
# Out:
# 0    star prices star service
# 1    villa pool private tired
# 2    maintenance man hotels issues hard
# Name: keywords, dtype: object

# %%
keyword_docs = list(nlp2.pipe(keywords,
  batch_size=10000,
  n_threads=3))

# %%
keyword_vectors = np.array([doc.vector 
  if doc.has_vector else nlp2.vocab[0].vector
  for doc in keyword_docs])

# %% [markdown]
# Now I have the vector for every sentence, I'm able to find the topic for each of them by measuring similarity between sentence vectors and topic vectors and picking the one with the largest likelyhood. I could define a threshold in the case of the similarity within every topic is too low and save it into a "something else" topic.

# %%
from sklearn.metrics.pairwise import cosine_similarity
# use numpy and scikit-learn vectorized implementations for performance
simple_sim = cosine_similarity(keyword_vectors, topic_vectors)
topic_idx = simple_sim.argmax(axis=1)

topic=[]
probability=[]
for k, i, j in zip(keywords, topic_idx,simple_sim):
    probability.append(j[i])
    if j[i] > 0.55:
        topic.append(topic_labels[i])
    else:
        topic.append("something else")

# %%
dm3['topic']=topic
dm3['probability']=probability

# %% [markdown]
# Have a look how topics distribute. Its seems Food & Bevarage has the less of mentions, meanwhile enviroment is the largest category.

# %%
dm3.topic.value_counts()
# Out:
# Environment        4095
# something else     2039
# Housekeeping       1484
# Front desk         1163
# Food & Beverage    755
# Name: topic, dtype: int64

# %%
dm3[dm3.topic=='Front desk'].sample(5)
# Out:
#       index  \
# 1064  195
# 8317  1620
# 1426  272
# 7218  1429
# 7246  1435
#
#                                                                                                                                                                 sent  \
# 1064  We were greeted warmly by Laura at reception.
# 8317  Staff are not overly friendly, but they do do the job, I guess.
# 1426  Our mini bar fridge broke down on day 2 and we had a new one within the hour.
# 7218  Overall we were extremely happy with the stay.
# 7246  When we came at the front desk for looking for our over the phone reservation, we were informed that as locals we have an upgrade, which we were very pleased.
#
#                                                             titulo  califica  \
# 1064  A wonderful escape from Melbourne's Winter                    50
# 8317  NYE party was very overpriced and boring. Resort was pretty.  40
# 1426  The perfect stay!                                             50
# 7218  Excellent Stay                                                40
# 7246  impressed by the customer service                             50
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               comentario  \
# 1064  We were greeted warmly by Laura at reception. She continued her personal interest in us throughout our stay. The front entrance is spacious and inviting with the lagoon pool beyond.
# 8317  A little bit out of the PD central shopping area. I would recommend a car for quick trips in and around. We had a car and it was great. They have free parking for you and some under cover as well.  The pool is vast and very, very pretty. The internet is only by cable. There is no wireless, so iPad and iPhone works only around the pool and lobby.  It does lack sunbeds & towels. The food by the pool and the Aqua restaurant is not like other resorts where the food is amazing and worth the crazy prices . I suggest going into PD for that stuff.  Staff are not overly friendly, but they do do the job, I guess. The NYE party which we booked was dead by 9:30pm. The buffet was $140 each, it included a welcome beverage and a buffet style dinner. The food was less than average.  The seafood area comprised of cold bugs, oysters and prawns and one cooked fish. The scallops area (cooked) was very popular, but  under serviced. The poor cook was overworked and had to leave the station to get more scallops. Meat buffet area was not very tasty and the cook there was rude. That was it! We finished our dinner by 7pm and then retreated to the bar area (which was dead). We were the only ones there. The band as a soloist singer on karaoke style stage. She was average.  We left after 9:30pm when more than half the guests had left. and the singer had a cd on for over half and hour.
# 1426  We stayed here for a week. Our holiday intentions were relaxation and thats exactly what we got with Port Douglas and the Pullman. The service by staff in all areas of the resort (reception, restaurant, pool bar etc) were all exceptional and on the same level. As soon as we checked in we were given a map of the resort and Port Douglas and provided with information about where to eat and where to go. The room was very clean and close to the pool! Our mini bar fridge broke down on day 2 and we had a new one within the hour. The staff were very efficient and accommodating in regard to this. We loved the amazing 3000 square pool and used it everyday. The restaurant had great food and coffee. We would highly recommend the Pullman to family and friends and we will definitely be staying at the Pullman again the next time we are in Port Douglas.
# 7218  Our family of 5 (children aged 11, 9 and 7) stayed at the Sea Temple Port Douglas for the second week of January.  Overall we were extremely happy with the stay.  The staff were all friendly and nothing was too much trouble.  We had a swim up apartment which was sensational as it meant the adults could relax while the kids were in the pool.  The apartment that we were first assigned was technically a swim up apartment but it was next to a very shallow and narrow end of one of the lagoons off of the main pool near a bridge.  We were all very disappointed as we were expecting to be near the main part of the pool.  We raised this and fortunately were moved to an apartment that faced the middle of the main part of the pool.  We loved this.  If I was to book again I would try to book a specific apartment because there are many "swim up" apartments but they are not all as well located as the one we ended up with.  The food in the restaurant was nice enough but not exceptional given the price.  I would make a similar comment about the room service food (which came from the restaurant).
# 7246  When we came at the front desk for looking for our over the phone reservation, we were informed that as locals we have an upgrade, which we were very pleased.
#
#                 fecha  \
# 1064  9 August 2017
# 8317  2 January 2012
# 1426  4 May 2017
# 7218  20 January 2013
# 7246  10 January 2013
#
#                                                                                                                                                                                                   new_col  \
# 1064  (We, were, greeted, warmly, by, Laura, at, reception, .)
# 8317  (Staff, are, not, overly, friendly, ,, but, they, do, do, the, job, ,, I, guess, .)
# 1426  (Our, mini, bar, fridge, broke, down, on, day, 2, and, we, had, a, new, one, within, the, hour, .)
# 7218  (Overall, we, were, extremely, happy, with, the, stay, .)
# 7246  (When, we, came, at, the, front, desk, for, looking, for, our, over, the, phone, reservation, ,, we, were, informed, that, as, locals, we, have, an, upgrade, ,, which, we, were, very, pleased, .)
#
#                                                          keywords       topic  \
# 1064  [reception]                                                  Front desk
# 8317  [Staff, job, not, friendly]                                  Front desk
# 1426  [mini, bar, fridge, day, hour, new]                          Front desk
# 7218  [stay, happy]                                                Front desk
# 7246  [desk, phone, reservation, locals, upgrade, front, pleased]  Front desk
#
#       probability     fecha2
# 1064  0.717266    2017-08-09
# 8317  0.640799    2012-01-02
# 1426  0.640787    2017-05-04
# 7218  0.571660    2013-01-20
# 7246  0.827138    2013-01-10

# %% [markdown]
# Since I have our sentences classified I'm hable to show its distribution through time.

# %%
dm3['fecha2'] = pd.to_datetime(dm3.fecha,format='%d %B %Y')
dmd = dm3.copy()
dmd.index = dmd['fecha2']
dmd.index = pd.to_datetime(dmd.index)
dmd = dmd.sort_values('fecha2')

# %%
cat=pd.crosstab(dmd.fecha2, dmd.topic)
cat=cat.resample(rule='M').sum()
cat['total']=cat.sum(axis=1)
cat=cat.div(cat.total,0)
cat=cat.drop('total',1)
cat.head()
#fig = plt.figure()
#plt.plot(cat.index, cat, marker='|', lw=0, ms=10)
#plt.ylim([-0.5, 5.5])
# Out:
# topic       Environment  Food & Beverage  Front desk  Housekeeping  \
# fecha2
# 2006-12-31  0.230769     0.076923         0.153846    0.230769
# 2007-01-31  0.384615     0.076923         0.153846    0.230769
# 2007-02-28  0.333333     0.000000         0.083333    0.250000
# 2007-03-31  0.500000     0.000000         0.000000    0.166667
# 2007-04-30  0.272727     0.000000         0.181818    0.181818
#
# topic       something else
# fecha2
# 2006-12-31  0.307692
# 2007-01-31  0.153846
# 2007-02-28  0.333333
# 2007-03-31  0.333333
# 2007-04-30  0.363636

# %%
cat.plot(kind='area')

# %% [markdown]
# ## Other way to classify reviews: LDA
#
# I used word2vec to automatic classify sentences. But thre si other options available. We could do some topic modeling. The standard algorithm is Latent Dirichlet Allocations or LDA, which will cluster sentences in a given number of topics. We have several ways to procced here.

# %% [markdown]
# ### Guided LDA

# %% [markdown]
# ### LDA AND word2Vec

# %% [markdown]
# # Sentiment analysis
#
# So far I have seen how frequently each section got named, but I don't have idea if it is positive or negative. As most reviews give a high score to the resort we could asumme that most comments are positive, but its not necessary. To do these we could use pre-build polarity sentiment models.

# %%
def nltk_sentiment(sentence):
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    
    nltk_sentiment = SentimentIntensityAnalyzer()
    score = nltk_sentiment.polarity_scores(sentence)
    return score

# %%
nltk_results = [nltk_sentiment(row) for row in dm3.sent]
# Out:
# C:\Users\Cami\Anaconda2\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
results_df = pd.DataFrame(nltk_results)
#text_df = pd.DataFrame(dataset, columns = ['text'])
dm4 = dm3.join(results_df)

# %%
dm4.columns
# Out:
# Index([      u'index',        u'sent',      u'titulo',    u'califica',
#         u'comentario',       u'fecha',     u'new_col',    u'keywords',
#              u'topic', u'probability',      u'fecha2',    u'compound',
#                u'neg',         u'neu',         u'pos'],
#       dtype='object')

# %%
dm4['fecha2'] = pd.to_datetime(dm4.fecha,format='%d %B %Y')
dmds = dm4.copy()
dmds.index = dmds['fecha2']
dmds.index = pd.to_datetime(dmds.index)
dmds = dmds.sort_values('fecha2')

# %%
sen=pd.pivot_table(dmds, values='compound', index=['fecha2'],columns=['topic'], aggfunc=np.mean)
sen=sen.resample(rule='M').mean()

# %%
sen.plot(kind='line')
